# %% [markdown]
# # Breast Cancer Detection

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ritti\Downloads\Breast_cancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.drop(columns=['id','Unnamed: 32'],inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.shape
# Out:
# (569, 31)

# %%
# to check given dataset is balanced or not
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
# handling imbalance dataset
# 1 - undersampling - not recommendad(info loss)
# 2 - oversampling 
# 3 - use random forest
# 4 - SmoteTomek

# will implement it after spliting

# %%
df.tail(8)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 561         B        11.20         29.37           70.67      386.0
# 562         M        15.22         30.62          103.40      716.9
# 563         M        20.92         25.09          143.00     1347.0
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 561          0.07449           0.03558         0.00000              0.00000
# 562          0.10480           0.20870         0.25500              0.09429
# 563          0.10990           0.22360         0.31740              0.14740
# ...

# %%
for col in df.columns:
    print(col)
    print('max = ', df[col].max())
    print('min = ', df[col].min())
    print('\n')
# Out:
# diagnosis
# max =  M
# min =  B
#
#
# radius_mean
# max =  28.11
# min =  6.981
#
#
# texture_mean
# max =  39.28
# min =  9.71
#
#
# perimeter_mean
# max =  188.5
# min =  43.79
#
#
# area_mean
# max =  2501.0
# min =  143.5
#
#
# smoothness_mean
# max =  0.1634
# min =  0.05263
#
#
# compactness_mean
# max =  0.3454
# min =  0.01938
#
#
# concavity_mean
# max =  0.4268
# min =  0.0
#
#
# concave points_mean
# max =  0.2012
# min =  0.0
#
#
# symmetry_mean
# max =  0.304
# min =  0.106
#
#
# fractal_dimension_mean
# max =  0.09744
# min =  0.04996
#
#
# radius_se
# max =  2.873
# min =  0.1115
#
#
# texture_se
# max =  4.885
# min =  0.3602
#
#
# perimeter_se
# max =  21.98
# min =  0.757
#
#
# area_se
# max =  542.2
# min =  6.802
#
#
# smoothness_se
# max =  0.03113
# min =  0.001713
#
#
# compactness_se
# max =  0.1354
# min =  0.002252
#
#
# concavity_se
# max =  0.396
# min =  0.0
#
#
# concave points_se
# max =  0.05279
# min =  0.0
#
#
# symmetry_se
# max =  0.07895
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a grid of 4 rows and 9 columns
fig, axes = plt.subplots(4, 9, figsize=(20, 15))  
fig.tight_layout(pad=3.0)  # Adjust spacing between plots

# Flatten the axes array for easy indexing
axes = axes.flatten()

# Plot each column
for i, col in enumerate(df.columns):
    sns.boxplot(y=col, data=df, ax=axes[i])
    axes[i].set_title(col)

# Turn off any unused subplots (if there are more subplots than columns)
for j in range(len(df.columns), len(axes)):
    axes[j].axis('off')

# Display the plot
plt.show()

# %%
# import numpy as np
# for col in df.columns:
#     per25=df[col].quantile(0.25)
#     per75=df[col].quantile(0.75)
#     iqr=per75-per25
#     upper_limit=per75+1.5*iqr
#     lower_limit=per25-1.5*iqr


#     df_copy=df.copy()
#     df_copy[col]=np.where(
#         df_copy[col]>upper_limit,upper_limit,
#         np.where(
#             df_copy[col]<lower_limit,lower_limit,
#             df_copy[col]
#         )
#     )

#     df=df_copy

# to handle outliers

# %%
fig, axes = plt.subplots(4, 9, figsize=(20, 15))  
fig.tight_layout(pad=3.0) 
axes = axes.flatten()
for i, col in enumerate(df.columns):
    sns.boxplot(y=col, data=df, ax=axes[i],hue='diagnosis')
    axes[i].set_title(col)
for j in range(len(df.columns), len(axes)):
    axes[j].axis('off')
plt.show()

# %% [markdown]
# ## observation from above plot
# outliers in most of the features are important for model to distinguish between benign and malignant cases. Avoid capping these.
#
# For features with overlapping outliers between the classes, may be capped using your IQR method.

# %%
fig, axes = plt.subplots(4, 9, figsize=(20, 15))  
fig.tight_layout(pad=3.0) 
axes = axes.flatten()
for i, col in enumerate(df.columns):
    sns.histplot(x=col, data=df, ax=axes[i],kde=True)
    axes[i].set_title(col)
for j in range(len(df.columns), len(axes)):
    axes[j].axis('off')
plt.show()

# %%
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1})

# %%
X=df.drop(columns=['diagnosis'])
y=df['diagnosis']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=1)

# %%
y_train.value_counts()
# Out:
# diagnosis
# 1    269
# 0    157
# Name: count, dtype: int64

# %%
# upsampling

from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(random_state=42)
X_resampled,y_resampled=ros.fit_resample(X_train,y_train)

# %%
y_resampled.value_counts()
# Out:
# diagnosis
# 0    269
# 1    269
# Name: count, dtype: int64

# %%
# SMOTETomek
from imblearn.combine import SMOTETomek
STobj=SMOTETomek(random_state=42)
X_resampled2,y_resampled2=STobj.fit_resample(X_train,y_train)

# %%
y_resampled2.value_counts()
# Out:
# diagnosis
# 0    261
# 1    261
# Name: count, dtype: int64

# %%
X_resampled2.shape
# Out:
# (522, 30)

# %%
y_test.shape
# Out:
# (143,)

# %% [markdown]
# # All classification models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import  DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score, classification_report

# %%
classifiers={
    'lr':LogisticRegression(max_iter=100),
    'rf':RandomForestClassifier(),
    'gb':GradientBoostingClassifier(),
    'dt':DecisionTreeClassifier(),
    'ab':AdaBoostClassifier(),
    'svm':SVC(),
    'Knn':KNeighborsClassifier(),
    'nb':GaussianNB(),
}

# %%
import warnings
warnings.filterwarnings('ignore')
for name, clf in classifiers.items():
    clf.fit(X_resampled2,y_resampled2)
    y_pred=clf.predict(X_test)
    print(f"{name}:\n{classification_report(y_test, y_pred)}\n")
# Out:
# lr:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        55
#            1       0.97      0.94      0.95        88
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.94      0.94       143
# weighted avg       0.94      0.94      0.94       143
#
#
# rf:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93        55
#            1       0.94      0.97      0.96        88
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.94      0.94       143
# weighted avg       0.94      0.94      0.94       143
#
#
# gb:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        55
#            1       0.94      0.95      0.95        88
#
#     accuracy                           0.94       143
#    macro avg       0.93      0.93      0.93       143
# ...

# %%
for name, clf in classifiers.items():
    y_pred=clf.predict(X_resampled2)
    print(f"{name}:\n{classification_report(y_resampled2, y_pred)}\n")
# Out:
# lr:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       261
#            1       0.97      0.97      0.97       261
#
#     accuracy                           0.97       522
#    macro avg       0.97      0.97      0.97       522
# weighted avg       0.97      0.97      0.97       522
#
#
# rf:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       261
#            1       1.00      1.00      1.00       261
#
#     accuracy                           1.00       522
#    macro avg       1.00      1.00      1.00       522
# weighted avg       1.00      1.00      1.00       522
#
#
# gb:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       261
#            1       1.00      1.00      1.00       261
#
#     accuracy                           1.00       522
#    macro avg       1.00      1.00      1.00       522
# ...

# %% [markdown]
# best model is adaboost with 96% test accuracy and 100% train accuracy(dataset is not too large)

# %% [markdown]
# validate whether AdaBoost is truly the best choice

# %%
from sklearn.model_selection import cross_val_score

# %%
ab=AdaBoostClassifier()
scores=cross_val_score(ab,X_resampled2,y_resampled2,scoring='accuracy')
print(scores.mean())
# Out:
# 0.977051282051282

# %%
ab=AdaBoostClassifier()
scores=cross_val_score(ab,X_test,y_test,scoring='accuracy')
print(scores.mean())
# Out:
# 0.9302955665024631

# %%
# Model  Handles Imbalance    Training Speed     Sensitivity to Outliers   Dataset Size

# rf        Moderate             fast                     low            Small to Large
# ab         good                moderate                high            small to medium
# xgb        Excellent           fast                   moderate        medium to large
